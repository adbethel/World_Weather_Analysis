# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-56.000, high=80.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 882

# %%
#Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descrip = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]     
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descrip,
                          "Country": city_country})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 1 | kroya
# Processing Record 4 of Set 1 | narasannapeta
# Processing Record 5 of Set 1 | flagstaff
# Processing Record 6 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 1 | slavuta
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | olafsvik
# Processing Record 10 of Set 1 | nenjiang
# Processing Record 11 of Set 1 | vao
# Processing Record 12 of Set 1 | athabasca
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | cidreira
# Processing Record 15 of Set 1 | north bend
# Processing Record 16 of Set 1 | pangnirtung
# Processing Record 17 of Set 1 | sao filipe
# Processing Record 18 of Set 1 | faanui
# Processing Record 19 of Set 1 | rehoboth
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | kavaratti
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | bundaberg
# Processing Record 24 of Set 1 | cap malheureux
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | hasaki
# Processing Record 27 of Set 1 | meulaboh
# Processing Record 28 of Set 1 | banda aceh
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | madison
# Processing Record 33 of Set 1 | tonantins
# Processing Record 34 of Set 1 | bethel
# Processing Record 35 of Set 1 | haines junction
# Processing Record 36 of Set 1 | pavlohrad
# Processing Record 37 of Set 1 | durazno
# Processing Record 38 of Set 1 | ossora
# Processing Record 39 of Set 1 | parana
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | staroshcherbinovskaya
# Processing Record 42 of Set 1 | galle
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | omboue
# Processing Record 45 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | ponta do sol
# Processing Record 48 of Set 1 | sioux lookout
# Processing Record 49 of Set 1 | kotelnich
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | nanortalik
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | mamlyutka
# Processing Record 5 of Set 2 | chokurdakh
# Processing Record 6 of Set 2 | namanga
# Processing Record 7 of Set 2 | gwanda
# Processing Record 8 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 2 | nelson bay
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | high rock
# Processing Record 12 of Set 2 | lata
# Processing Record 13 of Set 2 | ayna
# Processing Record 14 of Set 2 | tocantins
# Processing Record 15 of Set 2 | butaritari
# Processing Record 16 of Set 2 | nome
# Processing Record 17 of Set 2 | galveston
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | umm lajj
# Processing Record 20 of Set 2 | beyneu
# Processing Record 21 of Set 2 | yigou
# Processing Record 22 of Set 2 | zhanakorgan
# Processing Record 23 of Set 2 | mount gambier
# Processing Record 24 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 2 | stornoway
# Processing Record 26 of Set 2 | satipo
# Processing Record 27 of Set 2 | imbituba
# Processing Record 28 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 2 | iqaluit
# Processing Record 30 of Set 2 | salaga
# Processing Record 31 of Set 2 | rocha
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | mayo
# Processing Record 34 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | waingapu
# Processing Record 37 of Set 2 | airai
# Processing Record 38 of Set 2 | kayes
# Processing Record 39 of Set 2 | fortuna
# Processing Record 40 of Set 2 | guangyuan
# Processing Record 41 of Set 2 | jumla
# Processing Record 42 of Set 2 | yurla
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | baykit
# Processing Record 46 of Set 2 | littleton
# Processing Record 47 of Set 2 | san patricio
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | carpinteria
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | grahamstown
# Processing Record 4 of Set 3 | punta arenas
# Processing Record 5 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 3 | callaguip
# Processing Record 7 of Set 3 | bulgan
# Processing Record 8 of Set 3 | ulladulla
# Processing Record 9 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | sembakung
# Processing Record 12 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 3 | dingle
# Processing Record 14 of Set 3 | raga
# Processing Record 15 of Set 3 | hervey bay
# Processing Record 16 of Set 3 | port lincoln
# Processing Record 17 of Set 3 | codrington
# Processing Record 18 of Set 3 | avera
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | vestmannaeyjar
# Processing Record 21 of Set 3 | souillac
# Processing Record 22 of Set 3 | provideniya
# Processing Record 23 of Set 3 | panaba
# Processing Record 24 of Set 3 | sisimiut
# Processing Record 25 of Set 3 | myitkyina
# Processing Record 26 of Set 3 | sergeyevka
# Processing Record 27 of Set 3 | yoshida
# Processing Record 28 of Set 3 | wenling
# Processing Record 29 of Set 3 | norman wells
# Processing Record 30 of Set 3 | port hardy
# Processing Record 31 of Set 3 | lavrentiya
# Processing Record 32 of Set 3 | kapaa
# Processing Record 33 of Set 3 | kodiak
# Processing Record 34 of Set 3 | ambilobe
# Processing Record 35 of Set 3 | bantry
# Processing Record 36 of Set 3 | agirish
# Processing Record 37 of Set 3 | albuquerque
# Processing Record 38 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 3 | hilo
# Processing Record 40 of Set 3 | ancud
# Processing Record 41 of Set 3 | namibe
# Processing Record 42 of Set 3 | grand gaube
# Processing Record 43 of Set 3 | chenzhou
# Processing Record 44 of Set 3 | kokstad
# Processing Record 45 of Set 3 | hobart
# Processing Record 46 of Set 3 | lewistown
# Processing Record 47 of Set 3 | tuktoyaktuk
# Processing Record 48 of Set 3 | bambous virieux
# Processing Record 49 of Set 3 | barcelona
# Processing Record 50 of Set 3 | anadyr
# Processing Record 1 of Set 4 | walvis bay
# Processing Record 2 of Set 4 | udachnyy
# Processing Record 3 of Set 4 | gat
# Processing Record 4 of Set 4 | comodoro rivadavia
# Processing Record 5 of Set 4 | we
# City not found. Skipping...
# Processing Record 6 of Set 4 | phoenix
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | awjilah
# Processing Record 10 of Set 4 | oranjestad
# Processing Record 11 of Set 4 | biak
# Processing Record 12 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 4 | nuuk
# Processing Record 14 of Set 4 | saint anthony
# Processing Record 15 of Set 4 | thomaston
# Processing Record 16 of Set 4 | sangar
# Processing Record 17 of Set 4 | krasnoselkup
# Processing Record 18 of Set 4 | glenn heights
# Processing Record 19 of Set 4 | talnakh
# Processing Record 20 of Set 4 | chapais
# Processing Record 21 of Set 4 | ascension
# Processing Record 22 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 4 | bengkulu
# Processing Record 24 of Set 4 | geraldton
# Processing Record 25 of Set 4 | concepcion del oro
# Processing Record 26 of Set 4 | yulara
# Processing Record 27 of Set 4 | surgut
# Processing Record 28 of Set 4 | panama city
# Processing Record 29 of Set 4 | victoria
# Processing Record 30 of Set 4 | sungurlu
# Processing Record 31 of Set 4 | quimper
# Processing Record 32 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 4 | batagay-alyta
# Processing Record 34 of Set 4 | margate
# Processing Record 35 of Set 4 | cayenne
# Processing Record 36 of Set 4 | sabha
# Processing Record 37 of Set 4 | eyl
# Processing Record 38 of Set 4 | langangen
# City not found. Skipping...
# Processing Record 39 of Set 4 | katsuura
# Processing Record 40 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 4 | dawson creek
# Processing Record 42 of Set 4 | arraial do cabo
# Processing Record 43 of Set 4 | oneida
# Processing Record 44 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 45 of Set 4 | simao
# Processing Record 46 of Set 4 | saskylakh
# Processing Record 47 of Set 4 | esperance
# Processing Record 48 of Set 4 | saldanha
# Processing Record 49 of Set 4 | port augusta
# Processing Record 50 of Set 4 | ust-kuyga
# Processing Record 1 of Set 5 | ixtapa
# Processing Record 2 of Set 5 | faridan
# City not found. Skipping...
# Processing Record 3 of Set 5 | la fleche
# Processing Record 4 of Set 5 | touros
# Processing Record 5 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 5 | viedma
# Processing Record 7 of Set 5 | shingu
# Processing Record 8 of Set 5 | bardiyah
# Processing Record 9 of Set 5 | westport
# Processing Record 10 of Set 5 | yerbogachen
# Processing Record 11 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 5 | tual
# Processing Record 15 of Set 5 | iranshahr
# Processing Record 16 of Set 5 | arlit
# Processing Record 17 of Set 5 | qasigiannguit
# Processing Record 18 of Set 5 | kolyshley
# Processing Record 19 of Set 5 | selestat
# Processing Record 20 of Set 5 | pandan
# Processing Record 21 of Set 5 | hambantota
# Processing Record 22 of Set 5 | ghosi
# Processing Record 23 of Set 5 | havoysund
# Processing Record 24 of Set 5 | do gonbadan
# Processing Record 25 of Set 5 | manono
# Processing Record 26 of Set 5 | sao joao da barra
# Processing Record 27 of Set 5 | tacna
# Processing Record 28 of Set 5 | peniche
# Processing Record 29 of Set 5 | shenkursk
# Processing Record 30 of Set 5 | wanning
# Processing Record 31 of Set 5 | nabire
# Processing Record 32 of Set 5 | whitehorse
# Processing Record 33 of Set 5 | charlestown
# Processing Record 34 of Set 5 | ahuatempan
# Processing Record 35 of Set 5 | purwodadi
# Processing Record 36 of Set 5 | lagos
# Processing Record 37 of Set 5 | kloulklubed
# Processing Record 38 of Set 5 | buraydah
# Processing Record 39 of Set 5 | sfantu gheorghe
# Processing Record 40 of Set 5 | minot
# Processing Record 41 of Set 5 | mezen
# Processing Record 42 of Set 5 | porbandar
# Processing Record 43 of Set 5 | san cristobal
# Processing Record 44 of Set 5 | atyashevo
# Processing Record 45 of Set 5 | chardara
# Processing Record 46 of Set 5 | straseni
# Processing Record 47 of Set 5 | upernavik
# Processing Record 48 of Set 5 | teya
# Processing Record 49 of Set 5 | fort-shevchenko
# Processing Record 50 of Set 5 | sar-e pul
# Processing Record 1 of Set 6 | dryden
# Processing Record 2 of Set 6 | mach
# Processing Record 3 of Set 6 | ketchikan
# Processing Record 4 of Set 6 | sola
# Processing Record 5 of Set 6 | presidencia roque saenz pena
# Processing Record 6 of Set 6 | hastings
# Processing Record 7 of Set 6 | mogadouro
# Processing Record 8 of Set 6 | coruripe
# Processing Record 9 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 10 of Set 6 | hobe sound
# Processing Record 11 of Set 6 | tambul
# City not found. Skipping...
# Processing Record 12 of Set 6 | kenai
# Processing Record 13 of Set 6 | ballina
# Processing Record 14 of Set 6 | coihaique
# Processing Record 15 of Set 6 | contagem
# Processing Record 16 of Set 6 | inta
# Processing Record 17 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 6 | cervo
# Processing Record 19 of Set 6 | albany
# Processing Record 20 of Set 6 | luderitz
# Processing Record 21 of Set 6 | ilan
# Processing Record 22 of Set 6 | puerto carreno
# Processing Record 23 of Set 6 | padang
# Processing Record 24 of Set 6 | kadaya
# Processing Record 25 of Set 6 | tura
# Processing Record 26 of Set 6 | bedele
# Processing Record 27 of Set 6 | ati
# Processing Record 28 of Set 6 | kachug
# Processing Record 29 of Set 6 | nizhnyaya tavda
# Processing Record 30 of Set 6 | nizhneangarsk
# Processing Record 31 of Set 6 | klaksvik
# Processing Record 32 of Set 6 | alekseyevsk
# Processing Record 33 of Set 6 | hofn
# Processing Record 34 of Set 6 | tucurui
# Processing Record 35 of Set 6 | boa vista
# Processing Record 36 of Set 6 | scottsbluff
# Processing Record 37 of Set 6 | deder
# Processing Record 38 of Set 6 | miyako
# Processing Record 39 of Set 6 | portland
# Processing Record 40 of Set 6 | east london
# Processing Record 41 of Set 6 | castrillon
# Processing Record 42 of Set 6 | praia
# Processing Record 43 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 44 of Set 6 | gamba
# Processing Record 45 of Set 6 | cherskiy
# Processing Record 46 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 6 | port elizabeth
# Processing Record 48 of Set 6 | vanimo
# Processing Record 49 of Set 6 | los llanos de aridane
# Processing Record 50 of Set 6 | katobu
# Processing Record 1 of Set 7 | quelimane
# Processing Record 2 of Set 7 | mehamn
# Processing Record 3 of Set 7 | bud
# Processing Record 4 of Set 7 | hami
# Processing Record 5 of Set 7 | bauchi
# Processing Record 6 of Set 7 | ghanzi
# Processing Record 7 of Set 7 | luan
# Processing Record 8 of Set 7 | terracina
# Processing Record 9 of Set 7 | chuy
# Processing Record 10 of Set 7 | upington
# Processing Record 11 of Set 7 | vrangel
# Processing Record 12 of Set 7 | bumba
# Processing Record 13 of Set 7 | nicoya
# Processing Record 14 of Set 7 | solnechnyy
# Processing Record 15 of Set 7 | amapa
# Processing Record 16 of Set 7 | barrow
# Processing Record 17 of Set 7 | mogadishu
# Processing Record 18 of Set 7 | vestmanna
# Processing Record 19 of Set 7 | isla vista
# Processing Record 20 of Set 7 | vila velha
# Processing Record 21 of Set 7 | aklavik
# Processing Record 22 of Set 7 | palana
# Processing Record 23 of Set 7 | dibulla
# Processing Record 24 of Set 7 | deshna
# City not found. Skipping...
# Processing Record 25 of Set 7 | abu samrah
# Processing Record 26 of Set 7 | turhal
# Processing Record 27 of Set 7 | menasha
# Processing Record 28 of Set 7 | morondava
# Processing Record 29 of Set 7 | mahebourg
# Processing Record 30 of Set 7 | kaitangata
# Processing Record 31 of Set 7 | urumqi
# Processing Record 32 of Set 7 | zeya
# Processing Record 33 of Set 7 | juneau
# Processing Record 34 of Set 7 | severo-kurilsk
# Processing Record 35 of Set 7 | kutum
# Processing Record 36 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 37 of Set 7 | adrar
# Processing Record 38 of Set 7 | champerico
# Processing Record 39 of Set 7 | sheridan
# Processing Record 40 of Set 7 | paamiut
# Processing Record 41 of Set 7 | rtishchevo
# Processing Record 42 of Set 7 | lorengau
# Processing Record 43 of Set 7 | luquillo
# Processing Record 44 of Set 7 | coquimbo
# Processing Record 45 of Set 7 | falmouth
# Processing Record 46 of Set 7 | tuatapere
# Processing Record 47 of Set 7 | talara
# Processing Record 48 of Set 7 | bathurst
# Processing Record 49 of Set 7 | novosheshminsk
# Processing Record 50 of Set 7 | puerto suarez
# Processing Record 1 of Set 8 | suao
# City not found. Skipping...
# Processing Record 2 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 8 | ulaanbaatar
# Processing Record 4 of Set 8 | port macquarie
# Processing Record 5 of Set 8 | kankan
# Processing Record 6 of Set 8 | connersville
# Processing Record 7 of Set 8 | huarmey
# Processing Record 8 of Set 8 | gravdal
# Processing Record 9 of Set 8 | pundaguitan
# Processing Record 10 of Set 8 | horsham
# Processing Record 11 of Set 8 | contamana
# Processing Record 12 of Set 8 | gao
# Processing Record 13 of Set 8 | conde
# Processing Record 14 of Set 8 | lindi
# Processing Record 15 of Set 8 | trinidad
# Processing Record 16 of Set 8 | locri
# Processing Record 17 of Set 8 | shestakovo
# Processing Record 18 of Set 8 | acapulco
# Processing Record 19 of Set 8 | divo
# Processing Record 20 of Set 8 | sobolevo
# Processing Record 21 of Set 8 | hobyo
# Processing Record 22 of Set 8 | tabou
# Processing Record 23 of Set 8 | port hedland
# Processing Record 24 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 8 | kulhudhuffushi
# Processing Record 26 of Set 8 | thornbury
# Processing Record 27 of Set 8 | flin flon
# Processing Record 28 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 8 | lubbock
# Processing Record 30 of Set 8 | pemba
# Processing Record 31 of Set 8 | kuna
# Processing Record 32 of Set 8 | fonte boa
# Processing Record 33 of Set 8 | husavik
# Processing Record 34 of Set 8 | ranchuelo
# Processing Record 35 of Set 8 | filiatra
# Processing Record 36 of Set 8 | buala
# Processing Record 37 of Set 8 | mandalgovi
# Processing Record 38 of Set 8 | tateyama
# Processing Record 39 of Set 8 | cabo san lucas
# Processing Record 40 of Set 8 | eureka
# Processing Record 41 of Set 8 | boras
# Processing Record 42 of Set 8 | grindavik
# Processing Record 43 of Set 8 | constitucion
# Processing Record 44 of Set 8 | komsomolskiy
# Processing Record 45 of Set 8 | homer
# Processing Record 46 of Set 8 | paris
# Processing Record 47 of Set 8 | marsh harbour
# Processing Record 48 of Set 8 | honningsvag
# Processing Record 49 of Set 8 | miri
# Processing Record 50 of Set 8 | khatanga
# Processing Record 1 of Set 9 | korla
# Processing Record 2 of Set 9 | voi
# Processing Record 3 of Set 9 | santa cruz
# Processing Record 4 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 9 | denau
# City not found. Skipping...
# Processing Record 6 of Set 9 | avila
# Processing Record 7 of Set 9 | novoagansk
# Processing Record 8 of Set 9 | ushuaia
# Processing Record 9 of Set 9 | la asuncion
# Processing Record 10 of Set 9 | tecoanapa
# Processing Record 11 of Set 9 | aleksandrov gay
# Processing Record 12 of Set 9 | havelock
# Processing Record 13 of Set 9 | christchurch
# Processing Record 14 of Set 9 | la rioja
# Processing Record 15 of Set 9 | kisanga
# Processing Record 16 of Set 9 | kropotkin
# Processing Record 17 of Set 9 | nikolskoye-na-cheremshane
# City not found. Skipping...
# Processing Record 18 of Set 9 | port blair
# Processing Record 19 of Set 9 | kemijarvi
# Processing Record 20 of Set 9 | taoudenni
# Processing Record 21 of Set 9 | ihosy
# Processing Record 22 of Set 9 | mount clemens
# Processing Record 23 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 9 | vila franca do campo
# Processing Record 25 of Set 9 | guerrero negro
# Processing Record 26 of Set 9 | kerrville
# Processing Record 27 of Set 9 | impfondo
# Processing Record 28 of Set 9 | plettenberg bay
# Processing Record 29 of Set 9 | kapit
# Processing Record 30 of Set 9 | tacuati
# Processing Record 31 of Set 9 | yanam
# Processing Record 32 of Set 9 | srednekolymsk
# Processing Record 33 of Set 9 | bairiki
# Processing Record 34 of Set 9 | vila
# Processing Record 35 of Set 9 | aykhal
# Processing Record 36 of Set 9 | carutapera
# Processing Record 37 of Set 9 | randolph
# Processing Record 38 of Set 9 | ust-maya
# Processing Record 39 of Set 9 | fengcheng
# Processing Record 40 of Set 9 | necochea
# Processing Record 41 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 9 | quzhou
# Processing Record 44 of Set 9 | ostrovnoy
# Processing Record 45 of Set 9 | dongzhen
# Processing Record 46 of Set 9 | gelibolu
# Processing Record 47 of Set 9 | sitrah
# Processing Record 48 of Set 9 | tamiahua
# Processing Record 49 of Set 9 | kahului
# Processing Record 50 of Set 9 | mata
# Processing Record 1 of Set 10 | oktyabrskiy
# Processing Record 2 of Set 10 | jining
# Processing Record 3 of Set 10 | behbahan
# Processing Record 4 of Set 10 | saryg-sep
# Processing Record 5 of Set 10 | quime
# Processing Record 6 of Set 10 | pemangkat
# Processing Record 7 of Set 10 | vigrestad
# Processing Record 8 of Set 10 | muros
# Processing Record 9 of Set 10 | pontianak
# Processing Record 10 of Set 10 | quatre cocos
# Processing Record 11 of Set 10 | teguldet
# Processing Record 12 of Set 10 | nytva
# Processing Record 13 of Set 10 | saint-francois
# Processing Record 14 of Set 10 | aswan
# Processing Record 15 of Set 10 | sokoni
# Processing Record 16 of Set 10 | taixing
# Processing Record 17 of Set 10 | mingaora
# Processing Record 18 of Set 10 | fairview
# Processing Record 19 of Set 10 | norilsk
# Processing Record 20 of Set 10 | mundra
# Processing Record 21 of Set 10 | negombo
# Processing Record 22 of Set 10 | olenegorsk
# Processing Record 23 of Set 10 | kruisfontein
# Processing Record 24 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 10 | sawakin
# Processing Record 26 of Set 10 | gazli
# Processing Record 27 of Set 10 | ahipara
# Processing Record 28 of Set 10 | glenwood springs
# Processing Record 29 of Set 10 | hun
# Processing Record 30 of Set 10 | new norfolk
# Processing Record 31 of Set 10 | jacqueville
# Processing Record 32 of Set 10 | iralaya
# Processing Record 33 of Set 10 | kalmunai
# Processing Record 34 of Set 10 | znamenskoye
# Processing Record 35 of Set 10 | kupang
# Processing Record 36 of Set 10 | evensk
# Processing Record 37 of Set 10 | chivilcoy
# Processing Record 38 of Set 10 | careiro da varzea
# Processing Record 39 of Set 10 | abnub
# Processing Record 40 of Set 10 | martin
# Processing Record 41 of Set 10 | anloga
# Processing Record 42 of Set 10 | gorontalo
# Processing Record 43 of Set 10 | vidim
# Processing Record 44 of Set 10 | santiago del estero
# Processing Record 45 of Set 10 | itarema
# Processing Record 46 of Set 10 | san policarpio
# Processing Record 47 of Set 10 | bilibino
# Processing Record 48 of Set 10 | atambua
# Processing Record 49 of Set 10 | santo antonio do ica
# Processing Record 50 of Set 10 | zawadzkie
# Processing Record 1 of Set 11 | prado
# Processing Record 2 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 11 | mareeba
# Processing Record 4 of Set 11 | mamou
# Processing Record 5 of Set 11 | fairbanks
# Processing Record 6 of Set 11 | valle de allende
# Processing Record 7 of Set 11 | rio grande
# Processing Record 8 of Set 11 | damietta
# Processing Record 9 of Set 11 | flinders
# Processing Record 10 of Set 11 | bubaque
# Processing Record 11 of Set 11 | santiago
# Processing Record 12 of Set 11 | gizo
# Processing Record 13 of Set 11 | khani
# Processing Record 14 of Set 11 | saint george
# Processing Record 15 of Set 11 | svetlaya
# Processing Record 16 of Set 11 | caxito
# Processing Record 17 of Set 11 | uri
# Processing Record 18 of Set 11 | fargo
# Processing Record 19 of Set 11 | hamilton
# Processing Record 20 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 21 of Set 11 | hay river
# Processing Record 22 of Set 11 | marienburg
# Processing Record 23 of Set 11 | caravelas
# Processing Record 24 of Set 11 | natitingou
# Processing Record 25 of Set 11 | hua hin
# Processing Record 26 of Set 11 | narsaq
# Processing Record 27 of Set 11 | mulege
# Processing Record 28 of Set 11 | cabedelo
# Processing Record 29 of Set 11 | beloha
# Processing Record 30 of Set 11 | harper
# Processing Record 31 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 32 of Set 11 | baker city
# Processing Record 33 of Set 11 | dunedin
# Processing Record 34 of Set 11 | rincon
# Processing Record 35 of Set 11 | asyut
# Processing Record 36 of Set 11 | vostok
# Processing Record 37 of Set 11 | soledad
# Processing Record 38 of Set 11 | yurginskoye
# Processing Record 39 of Set 11 | jinchang
# Processing Record 40 of Set 11 | jackson
# Processing Record 41 of Set 11 | nakusp
# Processing Record 42 of Set 11 | guiyang
# Processing Record 43 of Set 11 | tornio
# Processing Record 44 of Set 11 | tabriz
# Processing Record 45 of Set 11 | kununurra
# Processing Record 46 of Set 11 | yangambi
# Processing Record 47 of Set 11 | goderich
# Processing Record 48 of Set 11 | dhone
# Processing Record 49 of Set 11 | san andres
# Processing Record 50 of Set 11 | olhao
# Processing Record 1 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 12 | pochutla
# Processing Record 3 of Set 12 | alofi
# Processing Record 4 of Set 12 | cancun
# Processing Record 5 of Set 12 | pisco
# Processing Record 6 of Set 12 | san juan
# Processing Record 7 of Set 12 | orcopampa
# Processing Record 8 of Set 12 | koumac
# Processing Record 9 of Set 12 | butembo
# Processing Record 10 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 11 of Set 12 | warrington
# Processing Record 12 of Set 12 | kuala terengganu
# Processing Record 13 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 12 | denizli
# Processing Record 15 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 12 | balakhonovskoye
# Processing Record 17 of Set 12 | rawson
# Processing Record 18 of Set 12 | floriano
# Processing Record 19 of Set 12 | marabba
# Processing Record 20 of Set 12 | azar shahr
# City not found. Skipping...
# Processing Record 21 of Set 12 | namatanai
# Processing Record 22 of Set 12 | buzmeyin
# Processing Record 23 of Set 12 | inongo
# Processing Record 24 of Set 12 | te anau
# Processing Record 25 of Set 12 | richards bay
# Processing Record 26 of Set 12 | acajutla
# Processing Record 27 of Set 12 | panjab
# Processing Record 28 of Set 12 | buturlino
# Processing Record 29 of Set 12 | virginia beach
# Processing Record 30 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 12 | porto novo
# Processing Record 32 of Set 12 | batticaloa
# Processing Record 33 of Set 12 | whakatane
# Processing Record 34 of Set 12 | aracati
# Processing Record 35 of Set 12 | abilene
# Processing Record 36 of Set 12 | luau
# Processing Record 37 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 12 | saint combs
# City not found. Skipping...
# Processing Record 39 of Set 12 | lapua
# Processing Record 40 of Set 12 | jalu
# Processing Record 41 of Set 12 | laguna
# Processing Record 42 of Set 12 | inhambane
# Processing Record 43 of Set 12 | puerto escondido
# Processing Record 44 of Set 12 | okha
# Processing Record 45 of Set 12 | mbaiki
# Processing Record 46 of Set 12 | miquelon
# Processing Record 47 of Set 12 | coahuayana
# Processing Record 48 of Set 12 | jucurutu
# Processing Record 49 of Set 12 | pevek
# Processing Record 50 of Set 12 | asmar
# Processing Record 1 of Set 13 | kudahuvadhoo
# Processing Record 2 of Set 13 | kaeo
# Processing Record 3 of Set 13 | longyearbyen
# Processing Record 4 of Set 13 | boizenburg
# Processing Record 5 of Set 13 | xining
# Processing Record 6 of Set 13 | mao
# Processing Record 7 of Set 13 | kalabo
# Processing Record 8 of Set 13 | ahuimanu
# Processing Record 9 of Set 13 | hualmay
# Processing Record 10 of Set 13 | humaita
# Processing Record 11 of Set 13 | yaan
# Processing Record 12 of Set 13 | tessalit
# Processing Record 13 of Set 13 | plaster rock
# Processing Record 14 of Set 13 | boyolangu
# Processing Record 15 of Set 13 | camopi
# Processing Record 16 of Set 13 | canchungo
# Processing Record 17 of Set 13 | saint-joseph
# Processing Record 18 of Set 13 | cockburn town
# Processing Record 19 of Set 13 | akhmim
# Processing Record 20 of Set 13 | jiazi
# Processing Record 21 of Set 13 | muragachha
# City not found. Skipping...
# Processing Record 22 of Set 13 | tilichiki
# Processing Record 23 of Set 13 | beringovskiy
# Processing Record 24 of Set 13 | poso
# Processing Record 25 of Set 13 | aksarka
# Processing Record 26 of Set 13 | agua de dios
# Processing Record 27 of Set 13 | fare
# Processing Record 28 of Set 13 | poum
# Processing Record 29 of Set 13 | schattdorf
# Processing Record 30 of Set 13 | pierre
# Processing Record 31 of Set 13 | ilulissat
# Processing Record 32 of Set 13 | isangel
# Processing Record 33 of Set 13 | teahupoo
# Processing Record 34 of Set 13 | bonfim
# Processing Record 35 of Set 13 | chara
# Processing Record 36 of Set 13 | kismayo
# Processing Record 37 of Set 13 | vicksburg
# Processing Record 38 of Set 13 | dandong
# Processing Record 39 of Set 13 | boende
# Processing Record 40 of Set 13 | ugoofaaru
# Processing Record 41 of Set 13 | bontang
# Processing Record 42 of Set 13 | rio gallegos
# Processing Record 43 of Set 13 | puerto del rosario
# Processing Record 44 of Set 13 | rudbar
# Processing Record 45 of Set 13 | gander
# Processing Record 46 of Set 13 | penzance
# Processing Record 47 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 13 | atlantic city
# Processing Record 49 of Set 13 | turukhansk
# Processing Record 50 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 1 of Set 14 | ilabaya
# Processing Record 2 of Set 14 | sao jose da coroa grande
# Processing Record 3 of Set 14 | bartlesville
# Processing Record 4 of Set 14 | puerto leguizamo
# Processing Record 5 of Set 14 | myanaung
# Processing Record 6 of Set 14 | gewane
# Processing Record 7 of Set 14 | praya
# Processing Record 8 of Set 14 | clyde river
# Processing Record 9 of Set 14 | puerto lempira
# Processing Record 10 of Set 14 | port keats
# Processing Record 11 of Set 14 | dhidhdhoo
# Processing Record 12 of Set 14 | college
# Processing Record 13 of Set 14 | saint-pierre
# Processing Record 14 of Set 14 | leningradskiy
# Processing Record 15 of Set 14 | puerto maldonado
# Processing Record 16 of Set 14 | merauke
# Processing Record 17 of Set 14 | altamira
# Processing Record 18 of Set 14 | birjand
# Processing Record 19 of Set 14 | tongren
# Processing Record 20 of Set 14 | juventino rosas
# Processing Record 21 of Set 14 | waipawa
# Processing Record 22 of Set 14 | cooma
# Processing Record 23 of Set 14 | muravlenko
# Processing Record 24 of Set 14 | sarh
# Processing Record 25 of Set 14 | opunake
# Processing Record 26 of Set 14 | waycross
# Processing Record 27 of Set 14 | shenzhen
# Processing Record 28 of Set 14 | ostend
# Processing Record 29 of Set 14 | lazaro cardenas
# Processing Record 30 of Set 14 | melur
# Processing Record 31 of Set 14 | kumburgaz
# Processing Record 32 of Set 14 | alice springs
# Processing Record 33 of Set 14 | salinopolis
# Processing Record 34 of Set 14 | lakes entrance
# Processing Record 35 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 36 of Set 14 | manitouwadge
# Processing Record 37 of Set 14 | dikson
# Processing Record 38 of Set 14 | elat
# Processing Record 39 of Set 14 | tucuma
# Processing Record 40 of Set 14 | masyaf
# Processing Record 41 of Set 14 | methoni
# Processing Record 42 of Set 14 | porkhov
# Processing Record 43 of Set 14 | tezu
# Processing Record 44 of Set 14 | yumen
# Processing Record 45 of Set 14 | faya
# Processing Record 46 of Set 14 | la libertad
# Processing Record 47 of Set 14 | zamhlay
# City not found. Skipping...
# Processing Record 48 of Set 14 | yamethin
# Processing Record 49 of Set 14 | isiro
# Processing Record 50 of Set 14 | burica
# City not found. Skipping...
# Processing Record 1 of Set 15 | grafton
# Processing Record 2 of Set 15 | bonthe
# Processing Record 3 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 15 | finschhafen
# Processing Record 5 of Set 15 | quartucciu
# Processing Record 6 of Set 15 | naze
# Processing Record 7 of Set 15 | glendive
# Processing Record 8 of Set 15 | babushkin
# Processing Record 9 of Set 15 | zemaiciu naumiestis
# Processing Record 10 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 11 of Set 15 | usinsk
# Processing Record 12 of Set 15 | sitka
# Processing Record 13 of Set 15 | andros
# Processing Record 14 of Set 15 | kolondieba
# Processing Record 15 of Set 15 | erenhot
# Processing Record 16 of Set 15 | san luis
# Processing Record 17 of Set 15 | assiniboia
# Processing Record 18 of Set 15 | sao sebastiao
# Processing Record 19 of Set 15 | taganak
# Processing Record 20 of Set 15 | lompoc
# Processing Record 21 of Set 15 | ponta delgada
# Processing Record 22 of Set 15 | klichka
# Processing Record 23 of Set 15 | araouane
# Processing Record 24 of Set 15 | high level
# Processing Record 25 of Set 15 | san francisco
# Processing Record 26 of Set 15 | killybegs
# Processing Record 27 of Set 15 | kabakovo
# Processing Record 28 of Set 15 | tofield
# Processing Record 29 of Set 15 | sarangani
# Processing Record 30 of Set 15 | mountain brook
# Processing Record 31 of Set 15 | rosario
# Processing Record 32 of Set 15 | elizabeth city
# Processing Record 33 of Set 15 | wonthaggi
# Processing Record 34 of Set 15 | surt
# Processing Record 35 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 15 | moerai
# Processing Record 37 of Set 15 | mbanza-ngungu
# Processing Record 38 of Set 15 | asbe teferi
# Processing Record 39 of Set 15 | vallenar
# Processing Record 40 of Set 15 | rosetta
# Processing Record 41 of Set 15 | pskov
# Processing Record 42 of Set 15 | lano
# Processing Record 43 of Set 15 | baherden
# Processing Record 44 of Set 15 | severobaykalsk
# Processing Record 45 of Set 15 | la massana
# Processing Record 46 of Set 15 | moryakovskiy zaton
# Processing Record 47 of Set 15 | karangasem
# Processing Record 48 of Set 15 | neiafu
# Processing Record 49 of Set 15 | alyangula
# Processing Record 50 of Set 15 | huilong
# Processing Record 1 of Set 16 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 2 of Set 16 | sovetskiy
# Processing Record 3 of Set 16 | chingirlau
# Processing Record 4 of Set 16 | acari
# Processing Record 5 of Set 16 | blythe
# Processing Record 6 of Set 16 | manga
# Processing Record 7 of Set 16 | bowen
# Processing Record 8 of Set 16 | mercedes
# Processing Record 9 of Set 16 | graaff-reinet
# Processing Record 10 of Set 16 | bonavista
# Processing Record 11 of Set 16 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 16 | luganville
# Processing Record 13 of Set 16 | bolgatanga
# Processing Record 14 of Set 16 | zavallya
# Processing Record 15 of Set 16 | kabare
# Processing Record 16 of Set 16 | beeville
# Processing Record 17 of Set 16 | yarada
# Processing Record 18 of Set 16 | north platte
# Processing Record 19 of Set 16 | vannes
# Processing Record 20 of Set 16 | west bay
# Processing Record 21 of Set 16 | boden
# Processing Record 22 of Set 16 | shar
# Processing Record 23 of Set 16 | balkanabat
# Processing Record 24 of Set 16 | dijkot
# Processing Record 25 of Set 16 | deputatskiy
# Processing Record 26 of Set 16 | tevaitoa
# Processing Record 27 of Set 16 | pyu
# Processing Record 28 of Set 16 | fraserburgh
# Processing Record 29 of Set 16 | moscow
# Processing Record 30 of Set 16 | pouebo
# Processing Record 31 of Set 16 | bend
# Processing Record 32 of Set 16 | katangli
# Processing Record 33 of Set 16 | tamandare
# Processing Record 34 of Set 16 | maldonado
# Processing Record 35 of Set 16 | mahibadhoo
# Processing Record 36 of Set 16 | berdigestyakh
# Processing Record 37 of Set 16 | marzuq
# Processing Record 38 of Set 16 | corozal
# Processing Record 39 of Set 16 | batangafo
# Processing Record 40 of Set 16 | invercargill
# Processing Record 41 of Set 16 | persianovskiy
# Processing Record 42 of Set 16 | khuzhir
# Processing Record 43 of Set 16 | nemuro
# Processing Record 44 of Set 16 | muhos
# Processing Record 45 of Set 16 | erzin
# Processing Record 46 of Set 16 | dondo
# Processing Record 47 of Set 16 | zamora
# Processing Record 48 of Set 16 | iquitos
# Processing Record 49 of Set 16 | san carlos
# Processing Record 50 of Set 16 | baiquan
# Processing Record 1 of Set 17 | arnold
# Processing Record 2 of Set 17 | acarau
# Processing Record 3 of Set 17 | karratha
# Processing Record 4 of Set 17 | lagoa
# Processing Record 5 of Set 17 | thanjavur
# Processing Record 6 of Set 17 | pimentel
# Processing Record 7 of Set 17 | lahat
# Processing Record 8 of Set 17 | zhigansk
# Processing Record 9 of Set 17 | bindura
# Processing Record 10 of Set 17 | batsfjord
# Processing Record 11 of Set 17 | beirut
# Processing Record 12 of Set 17 | oistins
# Processing Record 13 of Set 17 | ngunguru
# Processing Record 14 of Set 17 | male
# Processing Record 15 of Set 17 | barentu
# Processing Record 16 of Set 17 | fredericksburg
# Processing Record 17 of Set 17 | diffa
# Processing Record 18 of Set 17 | carrick-on-suir
# Processing Record 19 of Set 17 | kalavad
# Processing Record 20 of Set 17 | poronaysk
# Processing Record 21 of Set 17 | buchanan
# Processing Record 22 of Set 17 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 17 | amuntai
# Processing Record 24 of Set 17 | nyzhnya duvanka
# Processing Record 25 of Set 17 | azimur
# City not found. Skipping...
# Processing Record 26 of Set 17 | kholodnyy
# Processing Record 27 of Set 17 | iquique
# Processing Record 28 of Set 17 | koshurnikovo
# Processing Record 29 of Set 17 | malangwa
# Processing Record 30 of Set 17 | medea
# Processing Record 31 of Set 17 | hanumangarh
# Processing Record 32 of Set 17 | opuwo
# Processing Record 33 of Set 17 | pafos
# Processing Record 34 of Set 17 | ust-nera
# Processing Record 35 of Set 17 | reyes
# Processing Record 36 of Set 17 | mackay
# Processing Record 37 of Set 17 | sabla
# Processing Record 38 of Set 17 | parabel
# Processing Record 39 of Set 17 | seminole
# Processing Record 40 of Set 17 | port-gentil
# Processing Record 41 of Set 17 | khorixas
# Processing Record 42 of Set 17 | rodrigues alves
# Processing Record 43 of Set 17 | soyo
# Processing Record 44 of Set 17 | mazatlan
# Processing Record 45 of Set 17 | dumas
# Processing Record 46 of Set 17 | kurumkan
# Processing Record 47 of Set 17 | goya
# Processing Record 48 of Set 17 | atbasar
# Processing Record 49 of Set 17 | moussoro
# Processing Record 50 of Set 17 | saint-augustin
# Processing Record 1 of Set 18 | savanur
# Processing Record 2 of Set 18 | kang
# Processing Record 3 of Set 18 | morant bay
# Processing Record 4 of Set 18 | yokadouma
# Processing Record 5 of Set 18 | mingguang
# Processing Record 6 of Set 18 | san joaquin
# Processing Record 7 of Set 18 | sabya
# Processing Record 8 of Set 18 | la ronge
# Processing Record 9 of Set 18 | qandala
# Processing Record 10 of Set 18 | jeremie
# Processing Record 11 of Set 18 | zhuhai
# Processing Record 12 of Set 18 | horni plana
# Processing Record 13 of Set 18 | mount isa
# Processing Record 14 of Set 18 | nandu
# Processing Record 15 of Set 18 | dianopolis
# City not found. Skipping...
# Processing Record 16 of Set 18 | beira
# Processing Record 17 of Set 18 | baixo guandu
# Processing Record 18 of Set 18 | estevan
# Processing Record 19 of Set 18 | damghan
# Processing Record 20 of Set 18 | padilla
# Processing Record 21 of Set 18 | nizwa
# Processing Record 22 of Set 18 | salalah
# Processing Record 23 of Set 18 | tanete
# Processing Record 24 of Set 18 | kimbe
# Processing Record 25 of Set 18 | cassilandia
# Processing Record 26 of Set 18 | kamenka
# Processing Record 27 of Set 18 | green river
# Processing Record 28 of Set 18 | lara
# Processing Record 29 of Set 18 | manavalakurichi
# Processing Record 30 of Set 18 | kirakira
# Processing Record 31 of Set 18 | vilyuysk
# Processing Record 32 of Set 18 | ilinsko-podomskoye
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 813

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Nikolskoye  59.7035   30.7861     24.80        92         100
# 1          Kroya  -7.6331  109.2461     76.59        87          98
# 2  Narasannapeta  18.4167   84.0500     67.87        87           2
# 3      Flagstaff  35.1981 -111.6513     44.26        35           0
# 4        Slavuta  50.3016   26.8651     26.58        87          33
# 5          Vaini -21.2000 -175.2000     82.56        89          75
# 6       Olafsvik  64.8945  -23.7142     38.80        72          97
# 7       Nenjiang  49.1833  125.2167    -20.43       100          92
# 8            Vao -22.6667  167.4833     76.68        71         100
# 9      Athabasca  54.7169 -113.2854      1.81        82          97
#
#    Wind Speed       Description Country
# 0       11.63        light snow      RU
# 1        2.42   overcast clouds      ID
# 2        4.38         clear sky      IN
# 3       12.66         clear sky      US
# 4        5.06  scattered clouds      UA
# 5       11.50        light rain      TO
# 6       18.92        light rain      IS
# 7        1.70   overcast clouds      CN
# 8       10.76   overcast clouds      NC
# 9       16.98   overcast clouds      CA

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Description', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Nikolskoye      RU  59.7035   30.7861     24.80        92         100
# 1          Kroya      ID  -7.6331  109.2461     76.59        87          98
# 2  Narasannapeta      IN  18.4167   84.0500     67.87        87           2
# 3      Flagstaff      US  35.1981 -111.6513     44.26        35           0
# 4        Slavuta      UA  50.3016   26.8651     26.58        87          33
# 5          Vaini      TO -21.2000 -175.2000     82.56        89          75
# 6       Olafsvik      IS  64.8945  -23.7142     38.80        72          97
# 7       Nenjiang      CN  49.1833  125.2167    -20.43       100          92
# 8            Vao      NC -22.6667  167.4833     76.68        71         100
# 9      Athabasca      CA  54.7169 -113.2854      1.81        82          97
#
#    Wind Speed       Description
# 0       11.63        light snow
# 1        2.42   overcast clouds
# 2        4.38         clear sky
# 3       12.66         clear sky
# 4        5.06  scattered clouds
# 5       11.50        light rain
# 6       18.92        light rain
# 7        1.70   overcast clouds
# 8       10.76   overcast clouds
# 9       16.98   overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %%
# Set the output file name
output_data_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label='City_ID')
